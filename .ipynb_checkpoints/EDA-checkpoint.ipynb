# %%
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#modeling

import scipy.stats as stats
import statsmodels.api as sm
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
#  Options 
pd.set_option("display.max_rows", 1091)

# %%
def generate_model(features,target):
    model = LinearRegression()
    model.fit(features, target)
    training_score = model.score(features,target)
    validation_score = cross_val_score(model,features, target, cv=10, scoring='r2').mean()
    return training_score , validation_score, model

# %%
def model_summary(features,target):
    features = sm.add_constant(features)
    model = sm.OLS(target,features)
    fit = model.fit()
    return fit.summary()

# %%
def remove_outlier(dataframe, column):
    q1 = dataframe[column].quantile(0.25)
    q3 = dataframe[column].quantile(0.75)
    iqr = q3-q1 
    lower_bound  = q1-1.5*iqr
    upper_bound = q3+1.5*iqr
    handled_outliers = dataframe.loc[(dataframe[column] > lower_bound) & (dataframe[column] < upper_bound)]
    return handled_outliers

# %%
def diagnostic_plot(x, y_log):
    plt.figure(figsize=(20,5))
    rgr = LinearRegression()
    rgr.fit(x,y_log)
    pred = rgr.predict(x)
    plt.subplot(1, 3, 2)
    res = y_log - pred
    plt.scatter(pred, res)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")
    plt.subplot(1, 3, 3)
    #Generates a probability plot of sample data against the quantiles of a
    # specified theoretical distribution
    stats.probplot(res, dist="norm", plot=plt)
    plt.title("Normal Q-Q plot")

# %%
pickle_in = open("feature_engineered.pkl","rb")
dataset = pickle.load(pickle_in)

# %%
dataset = dataset.sample(frac=1, random_state = 4).reset_index(drop=True)

# %%
target = dataset.loc[:, dataset.columns == 'price']
features = dataset.loc[:, dataset.columns != 'price']

# %%
features_train, features_test, target_train, target_test = train_test_split(features,target, test_size=0.2, random_state=42, )

# %%
#baseline features
bl_features = features_train.loc[:, ['item_package_quantity', 'gross_wieght', 'net_wieght',  'carat_CT', 'diamond_pcs']]
bl_train_dataset = pd.merge(bl_features, target_train, on= bl_features.index)

# %%
bl_train_dataset.drop(columns = ['key_0'], inplace = True)

# %%
sns.pairplot(bl_train_dataset)

# %%
fig, ax = plt.subplots(figsize=(10,10))  
sns.heatmap(bl_train_dataset.corr(), annot=True, vmin=-1, vmax=1, ax=ax );
plt.xlim(-0.7, 6)
plt.ylim(6,-0.7)
# Out:
# (6, -0.7)

# %%
bl_train_dataset.corr()
# Out:
#                        item_package_quantity  gross_wieght  net_wieght  \
# item_package_quantity               1.000000      0.315979    0.306844
# gross_wieght                        0.315979      1.000000    0.997496
# net_wieght                          0.306844      0.997496    1.000000
# carat_CT                            0.131610     -0.154603   -0.153957
# diamond_pcs                         0.169788     -0.145520   -0.145281
# price                               0.356742      0.656086    0.658197
#
#                        carat_CT  diamond_pcs     price
# item_package_quantity  0.131610     0.169788  0.356742
# gross_wieght          -0.154603    -0.145520  0.656086
# net_wieght            -0.153957    -0.145281  0.658197
# carat_CT               1.000000     0.812145  0.431430
# diamond_pcs            0.812145     1.000000  0.347688
# price                  0.431430     0.347688  1.000000

# %%
sns.distplot(bl_train_dataset['price'])

# %%
sns.boxplot(dataset['price'])

# %% [markdown]
# # Baseline

# %%
traning_score1, validation_score1 = generate_model(bl_features, target_train)

# %%
traning_score1
# Out:
# 0.7279384324998424

# %%
validation_score1
# Out:
# 0.6892219772308399

# %%
diagnostic_plot(bl_features, target_train['price'] )

# %%
model_summary(bl_features, target_train)
# Out:
# /Users/hi/anaconda3/envs/metis/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.726
# Method:                 Least Squares   F-statistic:                     439.9
# Date:                Wed, 18 Sep 2019   Prob (F-statistic):          1.74e-229
# Time:                        21:06:18   Log-Likelihood:                -5881.2
# No. Observations:                 828   AIC:                         1.177e+04
# Df Residuals:                     822   BIC:                         1.180e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -99.2502     31.437     -3.157      0.002    -160.957     -37.544
# item_package_quantity    76.7709     23.482      3.269      0.001      30.679     122.863
# gross_wieght            -12.4536     28.931     -0.430      0.667     -69.240      44.333
# net_wieght               95.6652     29.796      3.211      0.001      37.179     154.151
# carat_CT               1877.1648    113.884     16.483      0.000    1653.627    2100.702
# diamond_pcs               0.5275      0.721      0.732      0.464      -0.887       1.942
# ==============================================================================
# Omnibus:                      674.046   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24121.791
# Skew:                           3.403   Prob(JB):                         0.00
# Kurtosis:                      28.551   Cond. No.                         301.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Baseline without outliers

# %%
wo_outliers = remove_outlier(bl_train_dataset, 'price')

# %%
wo_outliers_features = wo_outliers.loc[:, ['item_package_quantity', 'net_wieght', 'carat_CT','diamond_pcs']]
wo_outliers_target = wo_outliers.loc[:, wo_outliers.columns == 'price']

# %%
sns.distplot(wo_outliers_target)

# %%
traning_score2, validation_score2 = generate_model(wo_outliers_features, wo_outliers_target)

# %%
model_summary(wo_outliers_features, wo_outliers_target)
# Out:
# /Users/hi/anaconda3/envs/metis/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.602
# Model:                            OLS   Adj. R-squared:                  0.600
# Method:                 Least Squares   F-statistic:                     276.2
# Date:                Wed, 18 Sep 2019   Prob (F-statistic):          1.57e-144
# Time:                        21:57:54   Log-Likelihood:                -4713.8
# No. Observations:                 736   AIC:                             9438.
# Df Residuals:                     731   BIC:                             9461.
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -12.0918     17.418     -0.694      0.488     -46.287      22.104
# item_package_quantity    64.5535     12.461      5.180      0.000      40.090      89.017
# net_wieght               59.6582      2.488     23.974      0.000      54.773      64.544
# carat_CT               1013.9677    105.859      9.578      0.000     806.144    1221.792
# diamond_pcs               3.2638      0.667      4.895      0.000       1.955       4.573
# ==============================================================================
# Omnibus:                      336.752   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1762.580
# Skew:                           2.054   Prob(JB):                         0.00
# Kurtosis:                       9.372   Cond. No.                         352.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
diagnostic_plot(wo_outliers_features, wo_outliers_target['price'] )

# %% [markdown]
# # Log transformation on price

# %%
sns.distplot(np.log(target_train['price']))

# %%
traning_score3, validation_score3 = generate_model(bl_features, np.log(target_train))

# %%
traning_score3
# Out:
# 0.6365251277241475

# %%
validation_score3
# Out:
# 0.589246171442851

# %%
model_summary(bl_features, np.log(target_train))
# Out:
# /Users/hi/anaconda3/envs/metis/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.634
# Method:                 Least Squares   F-statistic:                     287.9
# Date:                Wed, 18 Sep 2019   Prob (F-statistic):          7.26e-178
# Time:                        21:06:19   Log-Likelihood:                -556.36
# No. Observations:                 828   AIC:                             1125.
# Df Residuals:                     822   BIC:                             1153.
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     4.9629      0.051     98.001      0.000       4.864       5.062
# item_package_quantity     0.2311      0.038      6.110      0.000       0.157       0.305
# gross_wieght              0.1587      0.047      3.406      0.001       0.067       0.250
# net_wieght               -0.0690      0.048     -1.437      0.151      -0.163       0.025
# carat_CT                  2.4244      0.183     13.215      0.000       2.064       2.784
# diamond_pcs               0.0022      0.001      1.926      0.054    -4.3e-05       0.005
# ==============================================================================
# Omnibus:                       56.796   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              246.851
# Skew:                          -0.017   Prob(JB):                     2.49e-54
# Kurtosis:                       5.675   Cond. No.                         301.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
diagnostic_plot(bl_features, np.log(target_train['price']))

# %% [markdown]
# # Adding one-hot encoded features

# %%
sns.pairplot(dataset)

# %%
fig, ax = plt.subplots(figsize=(10,10))  
sns.heatmap(dataset.corr(), annot=True, vmin=-1, vmax=1, ax=ax );
plt.xlim(-0.7, 17)
plt.ylim(17,-0.7)
# Out:
# (17, -0.7)

# %%
# features_train, features_test, target_train, target_test

# %%
traning_score4, validation_score4 = generate_model(features_train, target_train)

# %%
traning_score4
# Out:
# 0.807247163066124

# %%
validation_score4
# Out:
# 0.7707319926150632

# %%
model_summary(features_train, target_train)
# Out:
# /Users/hi/anaconda3/envs/metis/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     226.7
# Date:                Wed, 18 Sep 2019   Prob (F-statistic):          6.56e-278
# Time:                        21:08:06   Log-Likelihood:                -5738.5
# No. Observations:                 828   AIC:                         1.151e+04
# Df Residuals:                     812   BIC:                         1.158e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   295.8030    164.493      1.798      0.073     -27.079     618.685
# item_package_quantity   189.4395     81.215      2.333      0.020      30.022     348.857
# ring                     98.5659     26.849      3.671      0.000      45.864     151.267
# earring                -106.3635     85.501     -1.244      0.214    -274.193      61.466
# brand_Malabar          -159.0168     26.607     -5.976      0.000    -211.244    -106.790
# brand_Mine              350.2832     89.809      3.900      0.000     173.997     526.569
# purity_KT              -606.2336    284.652     -2.130      0.033   -1164.974     -47.493
# gross_wieght            -38.2065     26.394     -1.448      0.148     -90.016      13.603
# net_wieght              121.7714     27.054      4.501      0.000      68.668     174.874
# carat_CT               1875.9669    103.910     18.054      0.000    1672.003    2079.931
# diamond_pcs              -0.8512      0.632     -1.347      0.178      -2.092       0.390
# gender_women             57.8515     38.900      1.487      0.137     -18.505     134.208
# metal_color_yellow       -0.9251     21.529     -0.043      0.966     -43.184      41.333
# g_cert_916               24.2849     25.018      0.971      0.332     -24.823      73.393
# g_cert_750              548.8616     37.906     14.480      0.000     474.457     623.267
# IGI_cert                259.4291     34.820      7.451      0.000     191.081     327.777
# GH                     -717.5747     75.960     -9.447      0.000    -866.675    -568.474
# ==============================================================================
# Omnibus:                      648.399   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28748.614
# Skew:                           3.114   Prob(JB):                         0.00
# Kurtosis:                      31.187   Cond. No.                     1.43e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.98e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
diagnostic_plot(features_train, target_train['price'])

# %% [markdown]
# I'll try first with all features then exclude the ones with low correlation with the price such as:
# * __Metal_color_yellow__
# * __g_cert_750__
# * __purity_KT__
# * __GH__
# * __Brand_mine__
#
# I'll also consider removing the __gross weight__ since it is highly correlated with the net weight.

# %% [markdown]
# # Excluding some features

# %%
f = features_train.loc[:,[  'brand_Malabar', 'purity_KT', 'net_wieght', 'carat_CT',
       'diamond_pcs', 'g_cert_750', 'IGI_cert'] ]

# %%
traning_score5, validation_score5 = generate_model(f, target_train)

# %%
diagnostic_plot(f, target_train['price'] )

# %%
model_summary(f, target_train)
# Out:
# /Users/hi/anaconda3/envs/metis/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.776
# Method:                 Least Squares   F-statistic:                     409.8
# Date:                Wed, 18 Sep 2019   Prob (F-statistic):          1.01e-262
# Time:                        21:38:21   Log-Likelihood:                -5797.6
# No. Observations:                 828   AIC:                         1.161e+04
# Df Residuals:                     820   BIC:                         1.165e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -371.2643    156.169     -2.377      0.018    -677.803     -64.726
# brand_Malabar  -114.9622     24.537     -4.685      0.000    -163.124     -66.800
# purity_KT       439.5978    186.016      2.363      0.018      74.474     804.722
# net_wieght       84.8193      2.184     38.831      0.000      80.532      89.107
# carat_CT       1760.8652    109.336     16.105      0.000    1546.254    1975.477
# diamond_pcs      -1.3444      0.668     -2.012      0.045      -2.656      -0.033
# g_cert_750      420.0076     36.786     11.418      0.000     347.802     492.213
# IGI_cert        157.6863     31.925      4.939      0.000      95.021     220.351
# ==============================================================================
# Omnibus:                      701.943   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32315.294
# Skew:                           3.527   Prob(JB):                         0.00
# Kurtosis:                      32.781   Cond. No.                         712.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# I'll try removing outliers

# %% [markdown]
# # The one!!

# %% [markdown]
# # One-hot encoding + without outliers + log transformation

# %%
merged_eng_train = pd.merge(features_train, target_train, on= features_train.index)
merged_eng_test = pd.merge(features_test, target_test, on= features_test.index)

# %%
engineered_train_wo_outliers= remove_outlier(merged_eng_train, 'price')
engineered_test_wo_outliers= remove_outlier(merged_eng_test, 'price')

# %%
#split target column from features column 
target_eng_wo_outliers = engineered_train_wo_outliers.loc[:, engineered_train_wo_outliers.columns == 'price']
features_eng_wo_outliers = engineered_train_wo_outliers.loc[:,['brand_Malabar', 'purity_KT', 'net_wieght', 'carat_CT', 'g_cert_750', 'IGI_cert']]

# %%
sns.set(style="whitegrid")
sns.boxplot(x=target_eng_wo_outliers)

# %%
sns.distplot(np.log(target_eng_wo_outliers))
np.log(target_eng_wo_outliers).mean()
# Out:
# price    5.693756
# dtype: float64

# %%
traning_score6, validation_score6, model = generate_model(features_eng_wo_outliers, np.log(target_eng_wo_outliers))

# %%
traning_score6
# Out:
# 0.7864901905800544

# %%
validation_score6
# Out:
# 0.7746474804253467

# %%
target_t= np.log(target_eng_wo_outliers)

# %%
engineered_test_wo_outliers_features = engineered_test_wo_outliers.loc[:, ['brand_Malabar', 'purity_KT', 'net_wieght', 'carat_CT', 'g_cert_750', 'IGI_cert']]
engineered_test_wo_outliers_target = engineered_test_wo_outliers.loc[:,engineered_test_wo_outliers.columns == 'price' ]

# %%
predictions = model.predict(engineered_test_wo_outliers_features)

# %%
model.score(engineered_test_wo_outliers_features, np.log(engineered_test_wo_outliers_target))
# Out:
# 0.6970320561527027

# %%
model_summary(features_eng_wo_outliers, np.log(target_eng_wo_outliers))
# Out:
# /Users/hi/anaconda3/envs/metis/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     447.6
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):          1.55e-240
# Time:                        00:29:44   Log-Likelihood:                -106.23
# No. Observations:                 736   AIC:                             226.5
# Df Residuals:                     729   BIC:                             258.7
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             4.7676      0.185     25.786      0.000       4.405       5.131
# brand_Malabar    -0.4678      0.027    -17.252      0.000      -0.521      -0.415
# purity_KT         0.4186      0.220      1.906      0.057      -0.013       0.850
# net_wieght        0.1723      0.005     33.809      0.000       0.162       0.182
# carat_CT          2.0625      0.154     13.371      0.000       1.760       2.365
# g_cert_750        0.5880      0.042     14.150      0.000       0.506       0.670
# IGI_cert          0.2637      0.035      7.567      0.000       0.195       0.332
# ==============================================================================
# Omnibus:                       70.449   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              436.322
# Skew:                          -0.041   Prob(JB):                     1.79e-95
# Kurtosis:                       6.771   Cond. No.                         123.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
diagnostic_plot(features_eng_wo_outliers, target_eng_wo_outliers['price'] )

# %%
merged_eng_dataset = pd.merge(features_eng_wo_outliers, target_eng_wo_outliers, on= features_eng_wo_outliers.index)

# %%
merged_eng_dataset.drop(columns = ['key_0'], inplace = True)

# %%
sns.pairplot(merged_eng_dataset)
